# %%
# import pandas for data analysis
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import datetime
from datetime import timedelta

# %matplotlib inline

# %%
# import data from file, generated by novelty.js
df = pd.read_csv("./results/EuropeanComissionENG_tfidf.csv", sep=";", quotechar='~', quoting=1)

# %%
# convert unix timestamp to pandas datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
# cut learning phase out
ndf = df[201:]
# ndf = ndfa[ndfa['timestamp'] > '2016-12-01']

# %%
# plot histogram
ax = ndf[['title','rate']].groupby(['rate']).agg('count').plot(kind='bar', legend=False)

# %%
fig = ax.get_figure()
fig.savefig('figures/exENGhist_tfidf.pdf')

# %%
ndf[['title','rate']].groupby(['rate']).agg('count')
# Out:
#       title
# rate
# 0       370
# 1       142
# 2        44
# 3        26

# %%
# create time series from a dataset
df = pd.read_csv("./results/PeterPrevcENG_tfidf.csv", sep=";", quotechar='~', quoting=1)
# convert unix timestamp to pandas datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
# cut learning phase out
ndfa = df[201:]

# %%
year = 2014; month = 1;
endYear = 2017; endMonth = 2;
intervalMonth = 2;

resultsdf = pd.DataFrame(columns=['Novelty Frequency', 'News'])
j = 0

# iterate over all months
while ((year < endYear) or (month < endMonth)):
    startDate = datetime.date(year, month, 1);
    
    # increase month
    month = month + intervalMonth
    if (month > 12):
        year = year + 1
        month = month % 12
    
    endDate = datetime.date(year, month, 1);
    
    #print(startDate, endDate, len(ndf))
    
    ndf = ndfa[(ndfa['timestamp'] > startDate) & (ndfa['timestamp'] < endDate)]
    results = ndf[['title','rate']].groupby(['rate']).agg('count')
    
    # print(results)
    
    res = [0, 0, 0, 0]
    for i in range(4):
        if (i in results['title']):
            res[i] = results['title'][i]
        else:
            res[i] = 0

    allitems = res[0] + res[1] + res[2] + res[3]
    if (allitems == 0):
        allitems = 0.1
    novelty = res[2] + res[3]    

    # print(startDate, endDate, len(ndf), novelty/allitems)
    resultsdf.loc[endDate] = [novelty/allitems, allitems]
    j = j + 1
    
resultsdf
# Out:
#             Novelty Frequency   News
# 2014-03-01           0.000000    0.1
# 2014-05-01           0.000000    0.1
# 2014-07-01           0.000000    0.1
# 2014-09-01           0.000000    0.1
# 2014-11-01           0.000000    0.1
# 2015-01-01           0.000000    0.1
# 2015-03-01           0.000000    0.1
# 2015-05-01           0.112903   62.0
# 2015-07-01           0.500000    2.0
# 2015-09-01           0.000000    0.1
# 2015-11-01           0.000000    0.1
# 2016-01-01           0.132530   83.0
# 2016-03-01           0.111588  233.0
# 2016-05-01           0.197183   71.0
# 2016-07-01           0.166667   12.0
# 2016-09-01           0.333333    3.0
# 2016-11-01           1.000000    2.0
# 2017-01-01           0.085714   70.0
# 2017-03-01           0.000000   44.0

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
ax2 = ax.twinx()

ax.set_label('Novelty Frequency')
ax2.set_label('Number of News')

width = 0.4

resultsdf['Novelty Frequency'].plot(kind='bar', color='green', ax=ax, position=1, width=0.4)
resultsdf['News'].plot(kind='bar', color='red',ax=ax2,position=0, width=0.4)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-a15d7be89e18> in <module>()
#       6 ax.set_label('Novelty Frequency')
#       7 ax2.set_label('Number of News')
# ----> 8 ax.xlabel('test')
#       9
#      10 width = 0.4
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlabel'

# %%
2 in results['title']
# Out:
# False

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for
# Out:
#   File "<ipython-input-140-a7a46e5d4e99>", line 1
#     print(1:3)
#            ^
# SyntaxError: invalid syntax
